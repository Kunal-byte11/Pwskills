# %% [markdown]
# ###  1 . What is the difference between descriptive statistics and inferential statistics? Explain with examples

# %% [markdown]
# #### Descriptive Statistics :
#
# 1.Summarizes data
#
# 2.Uses : Mean , Median , Mode , Variance , Charts
#
# 3.Eg:-"Average Salary = $ 5000"
#
# #### Inferential Statistics:
# 1.Makes predictions about population using Sample
#
# 2.uses:- hypothesis testing , Confidence interval
#
# 3.Eg:- "We are 95% confident salary is between 4k - 5k$"

# %% [markdown]
# ### 2.  What is sampling in statistics? Explain the differences between random and stratified sampling.

# %% [markdown]
# #### Sampling
#
# sample is the process of selecting a small group of data / sample from a large group / population to study and analyze
#
# #### Random Sampling:
#
# 1.everyone has equal chance to be selected
#
# 2.picking names from a box
#
# 3.when to use -
#
# a.Population is similar
#
# b. Each member has equal probability
#
# #### Stratified Sampling:
# 1.Divide population into layers /groups , then sample from each
#
# 2 Males & Female -> sample from both
#
# 3 Used when groups are different
#
# 4 sampling from are different
#
# 5 sampling from every category
#
# 6 strata = layers

# %% [markdown]
# #### 3 Define mean, median, and mode. Explain why these measures of central tendency are important.

# %% [markdown]
# 1 Mean:
# Mean is the average value of a dataset. It is calculated by adding all the values and dividing by the total number of values.
#
# Formula:
# Mean = (Sum of all values) / (Number of values)
#
# Example:
# For numbers 2, 4, 6 → Mean = (2 + 4 + 6) / 3 = 4
#
#
#
# 2 Median:
# Median is the middle value of a dataset when the numbers are arranged in ascending or descending order.
#
# Example:
# For numbers 3, 5, 7 → Median = 5
#
# If there are even numbers of values, the median is the average of the two middle numbers.
#
# Example:
#  2, 4, 6, 8 → Median = (4 + 6) / 2 = 5
#
#
#
# 3 Mode:
# Mode is the value that appears most frequently in a dataset.
#
# Example:
# 2, 3, 3, 5, 7 → Mode = 3
#
#
#
# Importance of Measures of Central Tendency
#
# They summarize large datasets into a single value.
#
# They help in understanding the general pattern of data.
#
# They make comparison between different datasets easier.
#
# They are widely used in statistics, economics, and research analysis.

# %% [markdown]
# ### 4.Explain skewness and kurtosis. What does a positive skew imply about the data?

# %% [markdown]
# ### Skewness and Kurtosis
#
# **1. Skewness**
#
# Skewness is a measure of the **asymmetry of a data distribution**. It shows whether the data values are skewed to the **left or right** instead of being perfectly symmetrical.
#
# - **Positive Skew (Right Skew):** Tail extends to the right side.
# - **Negative Skew (Left Skew):** Tail extends to the left side.
#
# ---
#
# **2. Kurtosis**
#
# Kurtosis measures the **peakedness or flatness of a data distribution** compared to a normal distribution. It shows how heavy or light the tails of the distribution are.
#
# **Types of Kurtosis:**
#
# - **Leptokurtic:** High peak and heavy tails.
# - **Mesokurtic:** Normal distribution shape.
# - **Platykurtic:** Flat peak and light tails.
#
# ---
#
# ### What does Positive Skew imply?
#
# A **positive skew** means the **tail of the distribution is longer on the right side**. Most data values are concentrated on the **left side**, while a few larger values extend to the right.
#
# **Example:**
# Income distribution is often positively skewed because most people earn moderate income while a few earn very high income.

# %% [markdown]
# ### Implement a Python program to compute the mean, median, and mode of a given list of numbers.

# %%
import pandas as pd
import numpy as np

from scipy import stats

numbers = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]

mean_value = np.mean(numbers)
medium_value = np.median(numbers)
mode_value = stats.mode(numbers)

print(mean_value)
print(medium_value)
print(mode_value)
# Out:
# 19.6
# 19.0
# ModeResult(mode=np.int64(12), count=np.int64(3))

# %% [markdown]
# ### Question 6: Compute the covariance and correlation coefficient between the following two datasets provided as lists in Python:

# %%
import numpy as np
import pandas as pd

list_x = [10, 20, 30, 40, 50]
list_y = [15, 25, 35, 45, 60]

covariance = np.cov(list_x,list_y)
correlation = np.corrcoef(list_x,list_y)

print(covariance)
print(correlation)
# Out:
# [[250. 275.]
#  [275. 305.]]
# [[1.         0.99589321]
#  [0.99589321 1.        ]]

# %% [markdown]
# ### Question 7: Write a Python script to draw a boxplot for the following numeric list and identify its outliers. Explain the result:
# ### data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35

# %%
import numpy as np
import matplotlib.pyplot as plt

data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]

# Boxplot
plt.boxplot(data)
plt.title("Boxplot of Data")
plt.show()

# Finding Outliers using IQR method
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = [x for x in data if x < lower_bound or x > upper_bound]

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Outliers:", outliers)
# Out:
# Q1: 17.25
# Q3: 23.25
# IQR: 6.0
# Outliers: [35]

# %% [markdown]
# ### Question 8: You are working as a data analyst in an e-commerce company. The
# ###marketing team wants to know if there is a relationship between advertising spend and
# ###daily sales.
# ###● Explain how you would use covariance and correlation to explore this
# ###relationship.
# ###● Write Python code to compute the correlation between the two lists:
# ###advertising_spend = [200, 250, 300, 400, 500]
# ###daily_sales = [2200, 2450, 2750, 3200, 4000]

# %%
import numpy as np

advertising_spend = [200, 250, 300, 400, 500]
daily_sales = [2200, 2450, 2750, 3200, 4000]

# Calculate covariance
covariance = np.cov(advertising_spend, daily_sales)

# Calculate correlation coefficient
correlation = np.corrcoef(advertising_spend, daily_sales)

print("Covariance Matrix:")
print(covariance)

print("\nCorrelation Matrix:")
print(correlation)
# Out:
# Covariance Matrix:
# [[ 14500.  84875.]
#  [ 84875. 503250.]]
#
# Correlation Matrix:
# [[1.         0.99358241]
#  [0.99358241 1.        ]]

# %% [markdown]
# ### Question 9: Your team has collected customer satisfaction survey data on a scale of 1-10 and wants to understand its distribution before launching a new product.
# ### ● Explain which summary statistics and visualizations (e.g. mean, standard
# ###deviation, histogram) you’d use.
# ###● Write Python code to create a histogram using Matplotlib for the survey data:
# ###survey_scores = [7, 8, 5, 9, 6, 7, 8, 9, 10, 4, 7, 6, 9, 8, 7]

# %%
import numpy as np

advertising_spend = [200, 250, 300, 400, 500]
daily_sales = [2200, 2450, 2750, 3200, 4000]

# Calculate covariance
covariance = np.cov(advertising_spend, daily_sales)

# Calculate correlation coefficient
correlation = np.corrcoef(advertising_spend, daily_sales)

print("Covariance Matrix:")
print(covariance)

print("\nCorrelation Matrix:")
print(correlation)
# Out:
# Covariance Matrix:
# [[ 14500.  84875.]
#  [ 84875. 503250.]]
#
# Correlation Matrix:
# [[1.         0.99358241]
#  [0.99358241 1.        ]]
